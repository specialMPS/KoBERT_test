# %%
# google drive mount

from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import numpy as np
import pandas as pd

# %%
wellness = pd.read_csv('/gdrive/My Drive/KoBERT/data/웰니스_대화_스크립트_데이터셋.csv')

# %%
wellness
# Out:
#                                              sentence emotion
# 0     제 감정이 이상해진 것 같아요. 남편만 보면 화가 치밀어 오르고 감정 조절이 안되요.      화남
# 1                            더 이상 내 감정을 내가 컨트롤 못 하겠어.     비참함
# 2                         하루종일 오르락내리락 롤러코스터 타는 기분이에요.     비참함
# 3                                   꼭 롤러코스터 타는 것 같아요.     두려움
# 4                          롤러코스터 타는 것처럼 기분이 왔다 갔다 해요.     우울함
# ...                                               ...     ...
# 5226             한숨 자고 일어나면 괜찮으려나? 해서 자고 일어났는데도 똑같아요.     괴로움
# 5227                            자고 나면 괜찮을 줄 알았는데 비슷해…     괴로움
# 5228                                 지금도 상태가 계속 안 좋아.     비참함
# 5229                       이게 제 마음과 상관없이 증상이 계속 나타나요.     괴로움
# 5230                    나이 들면 고쳐질 줄 알았는데…아직까지 계속 그래요.     괴로움
#
# [5231 rows x 2 columns]

# %%
wellness.emotion.unique()
# Out:
# array(['화남', '비참함', '두려움', '우울함', '괴로움', '중립', '놀람', '지루함', '피로함'],
#       dtype=object)

# %%
wellness.loc[wellness['emotion'] == '두려움', 'emotion'] = '긴장됨'

# %%
wellness.emotion.unique()
# Out:
# array(['화남', '비참함', '긴장됨', '우울함', '괴로움', '중립', '놀람', '지루함', '피로함'],
#       dtype=object)

# %% [markdown]
# ---

# %%
data_train = pd.read_excel('/gdrive/My Drive/KoBERT/data/감성대화말뭉치(최종데이터)_Training.xlsx')

# %%
data_train

# %%
dataset_2 = data_train.loc[:, ['감정_대분류', '감정_소분류', '사람문장1']]
dataset_2
# Out:
#       감정_대분류   감정_소분류                                              사람문장1
# 0         기쁨     신이 난                          아내가 드디어 출산하게 되어서 정말 신이 나.
# 1         불안  스트레스 받는            당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.
# 2         당황       당황            고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워.
# 3         기쁨     신이 난      재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.
# 4         기쁨       안도                       빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.
# ...      ...      ...                                                ...
# 40874     불안    혼란스러운  같이 사는 친구가 애완견을 데려왔는데 대부분 내가 돌보고 있어. 내가 주인인가 혼란...
# 40875     기쁨       안도                  지난주에 건강검진 결과가 나왔는데 정상이라고 결과가 나왔어.
# 40876     슬픔      우울한          엄마는 내 꿈인 작가를 응원해 주고는 했는데 지금은 안 그래. 너무 슬퍼.
# 40877     기쁨     감사하는            이렇게 좋은 운동 시설에서 경로 우대로 운동할 수 있다니 참 행운이야.
# 40878     불안  스트레스 받는                친구 관계가 너무 힘들어. 베푸는 만큼 돌아오지 않는 것 같아.
#
# [40879 rows x 3 columns]

# %%
dataset_2['emotion'] = np.nan
dataset_2.head()
# Out:
#   감정_대분류   감정_소분류                                          사람문장1  emotion
# 0     기쁨     신이 난                      아내가 드디어 출산하게 되어서 정말 신이 나.      NaN
# 1     불안  스트레스 받는        당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.      NaN
# 2     당황       당황        고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워.      NaN
# 3     기쁨     신이 난  재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.      NaN
# 4     기쁨       안도                   빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.      NaN

# %%
# 긍정감정
is_pleasant = (dataset_2['감정_대분류'] == '기쁨')| (dataset_2['감정_대분류'] == '기쁨 ')

# 부정감정
is_alarmed = ((dataset_2['감정_대분류'] == '당황') & (dataset_2['감정_소분류'] == '혼란스러운')) | (dataset_2['감정_소분류'] == '당황') | (dataset_2['감정_소분류'] == '충격 받은') | (dataset_2['감정_소분류'] == '당혹스러운')
is_tense = (dataset_2['감정_소분류'] == '불안') | (dataset_2['감정_소분류'] == '두려운') | (dataset_2['감정_소분류'] == '취약한') | (dataset_2['감정_소분류'] == '걱정스러운') | (dataset_2['감정_소분류'] == '조심스러운') | (dataset_2['감정_소분류'] == '초조한')
is_distressed = ((dataset_2['감정_대분류'] == '당황') & (dataset_2['감정_소분류'] == '고립된')) | ((dataset_2['감정_대분류'] == '불안') & (dataset_2['감정_소분류'] == '혼란스러운')) | (dataset_2['감정_소분류'] == '후회되는') | (dataset_2['감정_소분류'] == '상처') | (dataset_2['감정_소분류'] == '배신당한') | (dataset_2['감정_소분류'] == '억울한') | (dataset_2['감정_소분류'] == '괴로워하는') | (dataset_2['감정_소분류'] == '열등감') | (dataset_2['감정_소분류'] == '죄책감의') | (dataset_2['감정_소분류'] == '부끄러운')
is_upset = (dataset_2['감정_소분류'] == '분노') | (dataset_2['감정_소분류'] == '툴툴대는') | (dataset_2['감정_소분류'] == '방어적인') | (dataset_2['감정_소분류'] == '노여워하는') | (dataset_2['감정_소분류'] == '짜증내는') | (dataset_2['감정_소분류'] == '악의적인') | (dataset_2['감정_소분류'] == '안달하는') | (dataset_2['감정_소분류'] == '구역질 나는') | (dataset_2['감정_소분류'] == '노여워하는') | (dataset_2['감정_소분류'] == '성가신') | (dataset_2['감정_소분류'] == '환멸을 느끼는') | (dataset_2['감정_소분류'] == '혐오스러운') | (dataset_2['감정_소분류'] == '한심한')
is_miserable = (dataset_2['감정_소분류'] == '슬픔') | (dataset_2['감정_소분류'] == '좌절한') | (dataset_2['감정_소분류'] == '비통한') | (dataset_2['감정_소분류'] == '마비된') | (dataset_2['감정_소분류'] == '염세적인') | (dataset_2['감정_소분류'] == '가난한, 불우한') | (dataset_2['감정_소분류'] == '버려진')
is_gloomy = ((dataset_2['감정_대분류'] == '상처') & (dataset_2['감정_소분류'] == '고립된')) | (dataset_2['감정_소분류'] == '실망한') | (dataset_2['감정_소분류'] == '우울한') | (dataset_2['감정_소분류'] == '눈물이 나는') | (dataset_2['감정_소분류'] == '낙담한') | (dataset_2['감정_소분류'] == '외로운') | (dataset_2['감정_소분류'] == '스트레스 받는') | (dataset_2['감정_소분류'] == '질투하는')
is_bored = (dataset_2['감정_소분류'] == '회의적인')
is_tired = (dataset_2['감정_소분류'] == '남의 시선을 의식하는') | (dataset_2['감정_소분류'] == '희생된')

# %%
dataset_2.loc[is_pleasant, 'emotion'] = '기쁨'
dataset_2.loc[is_alarmed, 'emotion'] = '놀람'
dataset_2.loc[is_tense, 'emotion'] = '긴장됨'
dataset_2.loc[is_distressed, 'emotion'] = '괴로움'
dataset_2.loc[is_upset, 'emotion'] = '화남'
dataset_2.loc[is_miserable, 'emotion'] = '비참함'
dataset_2.loc[is_gloomy, 'emotion'] = '우울함'
dataset_2.loc[is_bored, 'emotion'] = '지루함'
dataset_2.loc[is_tired, 'emotion'] = '피로함'

# %%
dataset_2
# Out:
#       감정_대분류   감정_소분류                                              사람문장1  \
# 0         기쁨     신이 난                          아내가 드디어 출산하게 되어서 정말 신이 나.
# 1         불안  스트레스 받는            당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.
# 2         당황       당황            고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워.
# 3         기쁨     신이 난      재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.
# 4         기쁨       안도                       빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.
# ...      ...      ...                                                ...
# 40874     불안    혼란스러운  같이 사는 친구가 애완견을 데려왔는데 대부분 내가 돌보고 있어. 내가 주인인가 혼란...
# 40875     기쁨       안도                  지난주에 건강검진 결과가 나왔는데 정상이라고 결과가 나왔어.
# 40876     슬픔      우울한          엄마는 내 꿈인 작가를 응원해 주고는 했는데 지금은 안 그래. 너무 슬퍼.
# 40877     기쁨     감사하는            이렇게 좋은 운동 시설에서 경로 우대로 운동할 수 있다니 참 행운이야.
# 40878     불안  스트레스 받는                친구 관계가 너무 힘들어. 베푸는 만큼 돌아오지 않는 것 같아.
#
#       emotion
# 0          기쁨
# 1         우울함
# 2          놀람
# 3          기쁨
# ...

# %%
dataset_2[dataset_2.emotion.isnull()]
# Out:
# Empty DataFrame
# Columns: [감정_대분류, 감정_소분류, 사람문장1, emotion]
# Index: []

# %%
dataset_3 = dataset_2[['사람문장1', 'emotion']].rename(columns={'사람문장1':'sentence'})
dataset_3
# Out:
#                                                 sentence emotion
# 0                              아내가 드디어 출산하게 되어서 정말 신이 나.      기쁨
# 1                당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.     우울함
# 2                고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워.      놀람
# 3          재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.      기쁨
# 4                           빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.      기쁨
# ...                                                  ...     ...
# 40874  같이 사는 친구가 애완견을 데려왔는데 대부분 내가 돌보고 있어. 내가 주인인가 혼란...     괴로움
# 40875                  지난주에 건강검진 결과가 나왔는데 정상이라고 결과가 나왔어.      기쁨
# 40876          엄마는 내 꿈인 작가를 응원해 주고는 했는데 지금은 안 그래. 너무 슬퍼.     우울함
# 40877            이렇게 좋은 운동 시설에서 경로 우대로 운동할 수 있다니 참 행운이야.      기쁨
# 40878                친구 관계가 너무 힘들어. 베푸는 만큼 돌아오지 않는 것 같아.     우울함
#
# [40879 rows x 2 columns]

# %% [markdown]
# ---

# %%
data_val = pd.read_excel('/gdrive/My Drive/KoBERT/data/감성대화말뭉치(최종데이터)_Validation.xlsx')
data_val

# %%
dataset_2 = data_val.loc[:, ['감정_대분류', '감정_소분류', '사람문장1']]
dataset_2
# Out:
#      감정_대분류 감정_소분류                                              사람문장1
# 0        분노   툴툴대는                                    요즘 부모님과 많이 부딪혀.
# 1        슬픔    비통한                           엄마가 결국 집을 나갔어. 너무 너무 슬퍼.
# 2        불안  조심스러운                     학교에서 한 친구를 괴롭히는 무리에게 그만하라고 했어.
# 3        당황   죄책감의   이번에 팀장님이 간단한 조사 업무를 부탁하셨는데 내가 잘못 처리했어. 너무 절망적이야.
# 4        분노  노여워하는                  남편이 이혼할 때 위자료를 주지 않으려고 변호사를 고용했어.
# ...     ...    ...                                                ...
# 5125     기쁨     느긋                   부동산 임대 소득으로 현재 여유롭게 살 수 있어서 좋단다.
# 5126     불안   회의적인  폐결핵은 이미 완치된 것 같은데 약을 한 달이나 더 먹으라고 하네? 아직 안 나은 ...
# 5127     분노    좌절한    연애하고 싶은데 소개팅만 나가면 꽝이야. 이러다가 난 결혼 못 하고 늙어 죽을 거야.
# 5128     분노   안달하는       은행 대출이 막혀서 생활비를 구할 수가 없어. 이제 어떻게 살아야 하나 막막해.
# 5129     분노   짜증내는            자식들은 키워 준 은혜도 모르고 내게 오지도 않네. 너무 외롭고 슬퍼.
#
# [5130 rows x 3 columns]

# %%
# 긍정감정
is_pleasant = (dataset_2['감정_대분류'] == '기쁨')| (dataset_2['감정_대분류'] == '기쁨 ')

# 부정감정
is_alarmed = ((dataset_2['감정_대분류'] == '당황') & (dataset_2['감정_소분류'] == '혼란스러운')) | (dataset_2['감정_소분류'] == '당황') | (dataset_2['감정_소분류'] == '충격 받은') | (dataset_2['감정_소분류'] == '당혹스러운')
is_tense = (dataset_2['감정_소분류'] == '불안') | (dataset_2['감정_소분류'] == '두려운') | (dataset_2['감정_소분류'] == '취약한') | (dataset_2['감정_소분류'] == '걱정스러운') | (dataset_2['감정_소분류'] == '조심스러운') | (dataset_2['감정_소분류'] == '초조한')
is_distressed = ((dataset_2['감정_대분류'] == '당황') & (dataset_2['감정_소분류'] == '고립된')) | ((dataset_2['감정_대분류'] == '불안') & (dataset_2['감정_소분류'] == '혼란스러운')) | (dataset_2['감정_소분류'] == '후회되는') | (dataset_2['감정_소분류'] == '상처') | (dataset_2['감정_소분류'] == '배신당한') | (dataset_2['감정_소분류'] == '억울한') | (dataset_2['감정_소분류'] == '괴로워하는') | (dataset_2['감정_소분류'] == '열등감') | (dataset_2['감정_소분류'] == '죄책감의') | (dataset_2['감정_소분류'] == '부끄러운')
is_upset = (dataset_2['감정_소분류'] == '분노') | (dataset_2['감정_소분류'] == '툴툴대는') | (dataset_2['감정_소분류'] == '방어적인') | (dataset_2['감정_소분류'] == '노여워하는') | (dataset_2['감정_소분류'] == '짜증내는') | (dataset_2['감정_소분류'] == '악의적인') | (dataset_2['감정_소분류'] == '안달하는') | (dataset_2['감정_소분류'] == '구역질 나는') | (dataset_2['감정_소분류'] == '노여워하는') | (dataset_2['감정_소분류'] == '성가신') | (dataset_2['감정_소분류'] == '환멸을 느끼는') | (dataset_2['감정_소분류'] == '혐오스러운') | (dataset_2['감정_소분류'] == '한심한')
is_miserable = (dataset_2['감정_소분류'] == '슬픔') | (dataset_2['감정_소분류'] == '좌절한') | (dataset_2['감정_소분류'] == '비통한') | (dataset_2['감정_소분류'] == '마비된') | (dataset_2['감정_소분류'] == '염세적인') | (dataset_2['감정_소분류'] == '가난한, 불우한') | (dataset_2['감정_소분류'] == '버려진')
is_gloomy = ((dataset_2['감정_대분류'] == '상처') & (dataset_2['감정_소분류'] == '고립된')) | (dataset_2['감정_소분류'] == '실망한') | (dataset_2['감정_소분류'] == '우울한') | (dataset_2['감정_소분류'] == '눈물이 나는') | (dataset_2['감정_소분류'] == '낙담한') | (dataset_2['감정_소분류'] == '외로운') | (dataset_2['감정_소분류'] == '스트레스 받는') | (dataset_2['감정_소분류'] == '질투하는')
is_bored = (dataset_2['감정_소분류'] == '회의적인')
is_tired = (dataset_2['감정_소분류'] == '남의 시선을 의식하는') | (dataset_2['감정_소분류'] == '희생된')

# %%
dataset_2['emotion'] = np.nan
dataset_2.head()
# Out:
#   감정_대분류 감정_소분류                                             사람문장1  emotion
# 0     분노   툴툴대는                                   요즘 부모님과 많이 부딪혀.      NaN
# 1     슬픔    비통한                          엄마가 결국 집을 나갔어. 너무 너무 슬퍼.      NaN
# 2     불안  조심스러운                    학교에서 한 친구를 괴롭히는 무리에게 그만하라고 했어.      NaN
# 3     당황   죄책감의  이번에 팀장님이 간단한 조사 업무를 부탁하셨는데 내가 잘못 처리했어. 너무 절망적이야.      NaN
# 4     분노  노여워하는                 남편이 이혼할 때 위자료를 주지 않으려고 변호사를 고용했어.      NaN

# %%
dataset_2.loc[is_pleasant, 'emotion'] = '기쁨'
dataset_2.loc[is_alarmed, 'emotion'] = '놀람'
dataset_2.loc[is_tense, 'emotion'] = '긴장됨'
dataset_2.loc[is_distressed, 'emotion'] = '괴로움'
dataset_2.loc[is_upset, 'emotion'] = '화남'
dataset_2.loc[is_miserable, 'emotion'] = '비참함'
dataset_2.loc[is_gloomy, 'emotion'] = '우울함'
dataset_2.loc[is_bored, 'emotion'] = '지루함'
dataset_2.loc[is_tired, 'emotion'] = '피로함'

# %%
dataset_2[dataset_2.emotion.isnull()]
# Out:
# Empty DataFrame
# Columns: [감정_대분류, 감정_소분류, 사람문장1, emotion]
# Index: []

# %%
dataset_4 = dataset_2[['사람문장1', 'emotion']].rename(columns={'사람문장1':'sentence'})
dataset_4
# Out:
#                                                sentence emotion
# 0                                       요즘 부모님과 많이 부딪혀.      화남
# 1                              엄마가 결국 집을 나갔어. 너무 너무 슬퍼.     비참함
# 2                        학교에서 한 친구를 괴롭히는 무리에게 그만하라고 했어.     긴장됨
# 3      이번에 팀장님이 간단한 조사 업무를 부탁하셨는데 내가 잘못 처리했어. 너무 절망적이야.     괴로움
# 4                     남편이 이혼할 때 위자료를 주지 않으려고 변호사를 고용했어.      화남
# ...                                                 ...     ...
# 5125                   부동산 임대 소득으로 현재 여유롭게 살 수 있어서 좋단다.      기쁨
# 5126  폐결핵은 이미 완치된 것 같은데 약을 한 달이나 더 먹으라고 하네? 아직 안 나은 ...     지루함
# 5127    연애하고 싶은데 소개팅만 나가면 꽝이야. 이러다가 난 결혼 못 하고 늙어 죽을 거야.     비참함
# 5128       은행 대출이 막혀서 생활비를 구할 수가 없어. 이제 어떻게 살아야 하나 막막해.      화남
# 5129            자식들은 키워 준 은혜도 모르고 내게 오지도 않네. 너무 외롭고 슬퍼.      화남
#
# [5130 rows x 2 columns]

# %% [markdown]
# ---

# %%
dataset_final = pd.concat([wellness, dataset_3, dataset_4])
dataset_final
# Out:
#                                                sentence emotion
# 0       제 감정이 이상해진 것 같아요. 남편만 보면 화가 치밀어 오르고 감정 조절이 안되요.      화남
# 1                              더 이상 내 감정을 내가 컨트롤 못 하겠어.     비참함
# 2                           하루종일 오르락내리락 롤러코스터 타는 기분이에요.     비참함
# 3                                     꼭 롤러코스터 타는 것 같아요.     긴장됨
# 4                            롤러코스터 타는 것처럼 기분이 왔다 갔다 해요.     우울함
# ...                                                 ...     ...
# 5125                   부동산 임대 소득으로 현재 여유롭게 살 수 있어서 좋단다.      기쁨
# 5126  폐결핵은 이미 완치된 것 같은데 약을 한 달이나 더 먹으라고 하네? 아직 안 나은 ...     지루함
# 5127    연애하고 싶은데 소개팅만 나가면 꽝이야. 이러다가 난 결혼 못 하고 늙어 죽을 거야.     비참함
# 5128       은행 대출이 막혀서 생활비를 구할 수가 없어. 이제 어떻게 살아야 하나 막막해.      화남
# 5129            자식들은 키워 준 은혜도 모르고 내게 오지도 않네. 너무 외롭고 슬퍼.      화남
#
# [51240 rows x 2 columns]

# %%
dataset_final[dataset_final['emotion'].isnull()]
# Out:
# Empty DataFrame
# Columns: [sentence, emotion]
# Index: []

# %%
dataset_final.to_csv('/gdrive/My Drive/KoBERT/data/data_final.csv', index=False)

# %%
dataset_final.emotion.value_counts()
# Out:
# 화남     9612
# 괴로움    8096
# 기쁨     7572
# 우울함    7234
# 긴장됨    5526
# 비참함    5355
# 놀람     3163
# 중립     2115
# 피로함    1770
# 지루함     797
# Name: emotion, dtype: int64
